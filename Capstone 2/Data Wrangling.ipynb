# %% [markdown]
# # Capstone Project 2
# **Predicting stock prices with a neural network**

# %% [markdown]
# ## Introduction

# %% [markdown]
# The objective of this project is to use deep learning to predict movement in stocks using a deep learning model. We will be analyzing time series data from 3 major tech companies: Apple, Google, and Microsoft.

# %% [markdown]
# ## Data Wrangling
# Pulling data from the web using Quandl's API

# %%
import pandas as pd
import quandl
import datetime

# %%
def quandl_stocks(symbol, start_date=(2000, 1, 1), end_date=None):
    """
    symbol is a string representing a stock symbol, e.g. 'AAPL'
 
    start_date and end_date are tuples of integers representing the year, month,
    and day
 
    end_date defaults to the current date when None
    """
 
    query_list = ['WIKI' + '/' + symbol]
 
    start_date = datetime.date(*start_date)
 
    if end_date:
        end_date = datetime.date(*end_date)
    else:
        end_date = datetime.date.today()
 
    return quandl.get(query_list, 
            returns='pandas', 
            start_date=start_date,
            end_date=end_date,
            collapse='daily',
            order='asc'
            )

# %%
apple_df = quandl_stocks('AAPL', (2010, 1, 1), (2018, 12, 31))

# %%
apple_df.head()
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 2010-01-04            213.43            214.50           212.38
# 2010-01-05            214.60            215.59           213.25
# 2010-01-06            214.38            215.23           210.75
# 2010-01-07            211.75            212.00           209.05
# 2010-01-08            210.30            212.00           209.06
#
#             WIKI/AAPL - Close  WIKI/AAPL - Volume  WIKI/AAPL - Ex-Dividend  \
# Date
# 2010-01-04             214.01          17633200.0                      0.0
# 2010-01-05             214.38          21496600.0                      0.0
# 2010-01-06             210.97          19720000.0                      0.0
# 2010-01-07             210.58          17040400.0                      0.0
# 2010-01-08             211.98          15986100.0                      0.0
#
#             WIKI/AAPL - Split Ratio  WIKI/AAPL - Adj. Open  \
# Date
# 2010-01-04                      1.0              27.428730
# 2010-01-05                      1.0              27.579091
# 2010-01-06                      1.0              27.550818
# 2010-01-07                      1.0              27.212826
# 2010-01-08                      1.0              27.026481
#
#             WIKI/AAPL - Adj. High  WIKI/AAPL - Adj. Low  \
# Date
# 2010-01-04              27.566240             27.293790
# 2010-01-05              27.706320             27.405597
# 2010-01-06              27.660055             27.084312
# 2010-01-07              27.244955             26.865839
# 2010-01-08              27.244955             26.867124
#
#             WIKI/AAPL - Adj. Close  WIKI/AAPL - Adj. Volume
# Date
# 2010-01-04               27.503268              123432400.0
# 2010-01-05               27.550818              150476200.0
# 2010-01-06               27.112585              138040000.0
# 2010-01-07               27.062465              119282800.0
# 2010-01-08               27.242385              111902700.0

# %%
google_df = quandl_stocks('GOOGL', (2010, 1, 1), (2018, 12, 31))

# %%
google_df.head()
# Out:
#             WIKI/GOOGL - Open  WIKI/GOOGL - High  WIKI/GOOGL - Low  \
# Date
# 2010-01-04             626.95             629.51            624.24
# 2010-01-05             627.18             627.84            621.54
# 2010-01-06             625.86             625.86            606.36
# 2010-01-07             609.40             610.00            592.65
# 2010-01-08             592.00             603.25            589.11
#
#             WIKI/GOOGL - Close  WIKI/GOOGL - Volume  WIKI/GOOGL - Ex-Dividend  \
# Date
# 2010-01-04              626.75            3908400.0                       0.0
# 2010-01-05              623.99            6003300.0                       0.0
# 2010-01-06              608.26            7949400.0                       0.0
# 2010-01-07              594.10           12815700.0                       0.0
# 2010-01-08              602.02            9439100.0                       0.0
#
#             WIKI/GOOGL - Split Ratio  WIKI/GOOGL - Adj. Open  \
# Date
# 2010-01-04                       1.0              314.445664
# 2010-01-05                       1.0              314.561020
# 2010-01-06                       1.0              313.898976
# 2010-01-07                       1.0              305.643492
# 2010-01-08                       1.0              296.916553
#
#             WIKI/GOOGL - Adj. High  WIKI/GOOGL - Adj. Low  \
# Date
# 2010-01-04              315.729627             313.086468
# 2010-01-05              314.892042             311.732288
# 2010-01-06              313.898976             304.118786
# 2010-01-07              305.944421             297.242559
# 2010-01-08              302.558971             295.467079
#
#             WIKI/GOOGL - Adj. Close  WIKI/GOOGL - Adj. Volume
# Date
# 2010-01-04               314.345354                 3908400.0
# 2010-01-05               312.961081                 6003300.0
# 2010-01-06               305.071727                 7949400.0
# 2010-01-07               297.969804                12815700.0
# 2010-01-08               301.942066                 9439100.0

# %%
msft_df = quandl_stocks('MSFT', (2010, 1, 1), (2018, 12, 31))

# %%
msft_df.head()
# Out:
#             WIKI/MSFT - Open  WIKI/MSFT - High  WIKI/MSFT - Low  \
# Date
# 2010-01-04             30.62             31.10            30.59
# 2010-01-05             30.85             31.10            30.64
# 2010-01-06             30.88             31.08            30.52
# 2010-01-07             30.63             30.70            30.19
# 2010-01-08             30.28             30.88            30.24
#
#             WIKI/MSFT - Close  WIKI/MSFT - Volume  WIKI/MSFT - Ex-Dividend  \
# Date
# 2010-01-04             30.950          38409100.0                      0.0
# 2010-01-05             30.960          49749600.0                      0.0
# 2010-01-06             30.770          58182400.0                      0.0
# 2010-01-07             30.452          50559700.0                      0.0
# 2010-01-08             30.660          51197400.0                      0.0
#
#             WIKI/MSFT - Split Ratio  WIKI/MSFT - Adj. Open  \
# Date
# 2010-01-04                      1.0              24.885276
# 2010-01-05                      1.0              25.072201
# 2010-01-06                      1.0              25.096582
# 2010-01-07                      1.0              24.893404
# 2010-01-08                      1.0              24.608954
#
#             WIKI/MSFT - Adj. High  WIKI/MSFT - Adj. Low  \
# Date
# 2010-01-04              25.275379             24.860895
# 2010-01-05              25.275379             24.901531
# 2010-01-06              25.259125             24.804005
# 2010-01-07              24.950294             24.535810
# 2010-01-08              25.096582             24.576445
#
#             WIKI/MSFT - Adj. Close  WIKI/MSFT - Adj. Volume
# Date
# 2010-01-04               25.153472               38409100.0
# 2010-01-05               25.161599               49749600.0
# 2010-01-06               25.007183               58182400.0
# 2010-01-07               24.748741               50559700.0
# 2010-01-08               24.917785               51197400.0

# %% [markdown]
# Now that we've got our raw data, let's dump them to CSV files for further analysis.

# %%
apple_df.to_csv('/Users/jessemailhot/Documents/GitHub/springboard/Capstone 2/raw data/apple.csv')
google_df.to_csv('/Users/jessemailhot/Documents/GitHub/springboard/Capstone 2/raw data/google.csv')
msft_df.to_csv('/Users/jessemailhot/Documents/GitHub/springboard/Capstone 2/raw data/msft.csv')
